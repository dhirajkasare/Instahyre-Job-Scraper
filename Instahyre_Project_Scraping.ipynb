# %% [markdown]
# # Import important libraries

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By

# %% [markdown]
# # URL to scrape

# %%
URL = "https://www.instahyre.com/python-jobs"

# %% [markdown]
# # Initialize WebDriver

# %%
# Open the URL and wait for 5 seconds to ensure the page is fully loaded
driver = webdriver.Chrome()
driver.maximize_window()  # Maximize the browser window to full screen
driver.get(URL)
time.sleep(5)

# %% [markdown]
# # Extract Links from the Job Listings Page

# %%
job_links = []
page_count = 0
total_pages = 50  # Set the number of pages to scrape

# Scroll through the page and click on the next button to load more job listings
while page_count < total_pages:
    # Scroll to the bottom of the page to load new jobs
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(3)
    
    try:
        # Find the next button and click it to load more jobs
        next_button = driver.find_element(By.XPATH, '//*[@id="job-function-page"]/div[2]/div/div[1]/div[1]/div[21]/li[12]')
        next_button.click()
        page_count += 1
        time.sleep(3)
        
        # Collect job listing links
        job_elements = driver.find_elements(By.XPATH, '//div[@class="opportunity-go col-xs-1"]/a[@id="employer-profile-opportunity"]')
        for element in job_elements:
            href_value = element.get_attribute('href')
            job_links.append(href_value)
    except:
        pass

driver.quit()
print(f"Total links collected: {len(job_links)}")
# Out:
# Total links collected: 1000

# %% [markdown]
# # Defining the Function to Extract Data from Each Link

# %%
# This function will extract the required job details from each job listing page
def extract_data(driver):
    try:
        # Extract job details from the page
        title = driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/div[2]/div[2]/div/div/div[2]/div[1]/div[1]/h2').text
        job_position = driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/div[2]/div[2]/div/div/div[2]/div[1]/div[1]/h1').text
        location = driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/div[2]/div[2]/div/div/div[2]/div[1]/div[1]/div/span[1]').text
        founded = driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/div[2]/div[2]/div/div/div[1]/div[2]/div[1]').text
        employees = driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/div[2]/div[2]/div/div/div[1]/div[2]/div[2]').text
        about = driver.find_element(By.XPATH, '//*[@id="employer-summary"]/div[1]/div').text
        skills = driver.find_element(By.XPATH, '//*[@id="job-skills-description"]').text

        return {
            "Title": title,
            "Job Position": job_position,
            "Location": location,
            "Founded": founded,
            "Employees": employees,
            "About": about,
            "Skills": skills,
            "Link": driver.current_url
        }
    except:
        return None

# %% [markdown]
# # Initialize WebDriver and iterate through each job link to collect job details

# %%
driver = webdriver.Chrome()
driver.maximize_window()  # Maximize the browser window to full screen
extracted_data = []

for url in job_links:
    driver.get(url)
    time.sleep(3)  # Wait for the page to load
    data = extract_data(driver)
    if data:
        extracted_data.append(data)

driver.quit()
print("Data extraction completed")
# Out:
# Data extraction completed

# %% [markdown]
# # Convert to DataFrame and Save to CSV

# %%
# Convert to DataFrame
df = pd.DataFrame(extracted_data)
df
# Out:
#              Title                  Job Position  \
# 0           Arcana       Senior Backend Engineer
# 1        AheadRace     Senior Software Developer
# 2          Nielsen                 Data Engineer
# 3        NetSpring     Senior Fullstack Engineer
# 4        AheadRace           Sr. DevOps Engineer
# ..             ...                           ...
# 992      Salarybox                  Data Analyst
# 993        Tessell  Software Engineer - Postgres
# 994        Toplyne                Technical Lead
# 995   DealShare.in              Backend Engineer
# 996  SalesIntel.io              Backend Engineer
#
#                                   Location          Founded  \
# 0    Bangalore, Coimbatore, Work From Home  Founded in 2022
# 1                                   Mumbai  Founded in 2014
# 2                                Bangalore  Founded in 1923
# 3                           Work From Home  Founded in 2019
# 4                                   Mumbai  Founded in 2014
# ..                                     ...              ...
# 992                                Gurgaon  Founded in 2020
# 993                              Bangalore  Founded in 2021
# 994                              Bangalore  Founded in 2021
# 995                                   Pune  Founded in 2018
# 996                         Work From Home  Founded in 2018
#
#                     Employees  \
# 0           10 - 50 employees
# 1          50 - 200 employees
# 2    More than 1000 employees
# 3           10 - 50 employees
# 4          50 - 200 employees
# ..                        ...
# 992          0 - 10 employees
# 993         10 - 50 employees
# 994         10 - 50 employees
# 995      500 - 1000 employees
# 996        50 - 200 employees
#
#                                                  About  \
# 0    Arcana is on a mission to revolutionize the in...
# 1    Better insight, faster response, and quicker e...
# 2    Nielsen Holdings plc (NYSE: NLSN) is a global ...
# 3    NetSpring is a cloud application platform-as-a...
# 4    Better insight, faster response, and quicker e...
# ..                                                 ...
# 992  Salarybox is a YComibinator-backed startup fou...
# 993  Tessell delivers highly differentiated DBaaS o...
# 994  We're building a platform that sits over most ...
# 995  DealShare has a vision of enabling ecommerce f...
# 996  SalesIntel is a go-to-market intelligence plat...
#
#                                                 Skills  \
# 0                                       Django\nPython
# 1          Python\nDjango\nFlask\nAWS\nData Structures
# 2        Python\nAmazon RDS\nPySpark\nAirflow\nCI - CD
# 3           React.js\nPython\nNode.js\nJavaScript\nCSS
# 4              DevOps\nDocker\nKubernetes\nAWS\nPython
# ..                                                 ...
# 992          SQL\nETL\nData Analysis\nPython\nPower BI
# 993  Python\nPostgreSQL\nTerraform\nDistributed Sys...
# 994          Java\nPython\nData Structures\nMySQL\nLLD
# 995     Java\nC++\nPython\nData Structures\nAlgorithms
# 996                         Java\nAWS\nPython\nNode.js
#
#                                                   Link
# 0    https://www.instahyre.com/job-300223-senior-ba...
# 1    https://www.instahyre.com/job-329738-senior-so...
# 2    https://www.instahyre.com/job-329760-data-engi...
# 3    https://www.instahyre.com/job-326595-senior-fu...
# 4    https://www.instahyre.com/job-327569-sr-devops...
# ..                                                 ...
# 992  https://www.instahyre.com/job-323727-data-anal...
# 993  https://www.instahyre.com/job-324586-software-...
# 994  https://www.instahyre.com/job-319654-technical...
# 995  https://www.instahyre.com/job-311943-backend-e...
# 996  https://www.instahyre.com/job-317608-backend-e...
#
# [997 rows x 8 columns]

# %%
# Save to CSV
df.to_csv('Instahyre_Project_Scraped_File.csv', index=False)
